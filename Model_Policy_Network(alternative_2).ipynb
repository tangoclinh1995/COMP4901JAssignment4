# %% [markdown]
# # REMARKS
#
# In this **alternative version 2**:
# -  I try to ***clip*** the **predicted_reward** tensor by using sigmoid function, some shift and scaling. What I noticed while solving this notebook was that when predicted_reward was ***uncliped***, it would become overflow after a few dozen episodes.
#
# -  Similar to **alternative version 1**, I change the feed_dict in the sess.run(updateModel) command to:
#         {
#             previous_state: epXandAction,
#             true_observation: np.vstack([epx[1: ], observation]),
#             true_reward: epr,
#             true_done: epd
#         }
#
#    Please check the **REMARKS** at the beginning of **Model_Policy_Network(alternative_1).ipynb** for detailed explanation of why I change the feed_dict in this way.
#
#    Somehow, the **mean_reward** obatined in this alternative version is still smaller than in the main version. The reason is still unclear to me.

# %% [markdown]
# # Model-Based RL
# In this exercise you will implement a policy and model network which work in tandem to solve the CartPole reinforcement learning problem.

# %% [markdown]
# What is a model and why would we want to use one? In this case, a model is going to be a neural network that attempts to learn the dynamics of the real environment. For example, in the CartPole we would like a model to be able to predict the next position of the Cart given the previous position and an action. By learning an accurate model, we can train our agent using the model rather than requiring to use the real environment every time. While this may seem less useful when the real environment is itself a simulation, like in our CartPole task, it can have huge advantages when attempting to learn policies for acting in the physical world.

# %% [markdown]
# How are we going to accomplish this in Tensorflow? We are going to be using a neural network that will learn the transition dynamics between a previous observation and action, and the expected new observation, reward, and done state. Our training procedure will involve switching between training our model using the real environment, and training our agent’s policy using the model environment. By using this approach we will be able to learn a policy that allows our agent to solve the CartPole task without actually ever training the policy on the real environment!

# %% [markdown]
# ### Loading libraries and starting CartPole environment

# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# Hyperparameters
H = 8 # number of Hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # Discount factor for reward
decay_rate = 0.99 # Decay factor for RMSProp leaky sum of grad^2
resume = False # Resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# Nodel initialization
D = 4 # Input dimensionality

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph()

observations = tf.placeholder(tf.float32, [None, 4], name = "input_x")

W1 = tf.get_variable(
    "W1",
    shape = [4, H],
    initializer = tf.contrib.layers.xavier_initializer()
)
layer1 = tf.nn.relu(tf.matmul(observations, W1))

W2 = tf.get_variable(
    "W2",
    shape=[H, 1],
    initializer = tf.contrib.layers.xavier_initializer()
)

score = tf.matmul(layer1, W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()

input_y = tf.placeholder(tf.float32, [None, 1], name = "input_y")
advantages = tf.placeholder(tf.float32, name = "reward_signal")

adam = tf.train.AdamOptimizer(learning_rate = learning_rate)
W1Grad = tf.placeholder(tf.float32, name = "batch_grad1")
W2Grad = tf.placeholder(tf.float32, name = "batch_grad2")
batchGrad = [W1Grad, W2Grad]

################################################################################
# TODO: Implement the loss function.                                           #
# This sends the weights in the direction of making actions that gave good     #
# advantage (reward overtime) more likely, and actions that didn't less likely.#
################################################################################

logLikelihood = tf.log(
    (1 - input_y) * probability
    + input_y * (1 - probability)
)

loss = -tf.reduce_mean(logLikelihood * advantages)

################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

newGrads = tf.gradients(loss, tvars)
updateGrads = adam.apply_gradients(zip(batchGrad, tvars))

# %% [markdown]
# ### Model Network
# Here we implement a multi-layer neural network that predicts the next observation, reward, and done state from a current state and action.

# %%
mH = 256 # Model layer size

# input_data = tf.placeholder(tf.float32, [None, 5])  # Redundant ???

with tf.variable_scope("rnnlm"):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None, 5], name = "previous_state")

W1M = tf.get_variable(
    "W1M",
    shape = [5, mH],
    initializer = tf.contrib.layers.xavier_initializer()
)
B1M = tf.Variable(tf.zeros([mH]), name = "B1M")

layer1M = tf.nn.relu(tf.matmul(previous_state, W1M) + B1M)

W2M = tf.get_variable(
    "W2M",
    shape = [mH, mH],
    initializer = tf.contrib.layers.xavier_initializer()
)
B2M = tf.Variable(tf.zeros([mH]), name = "B2M")

layer2M = tf.nn.relu(tf.matmul(layer1M, W2M) + B2M)

wO = tf.get_variable(
    "wO",
    shape = [mH, 4],
    initializer = tf.contrib.layers.xavier_initializer()
)

wR = tf.get_variable(
    "wR",
    shape = [mH, 1],
    initializer = tf.contrib.layers.xavier_initializer()
)

wD = tf.get_variable(
    "wD",
    shape = [mH, 1],
    initializer = tf.contrib.layers.xavier_initializer()
)

bO = tf.Variable(tf.zeros([4]), name = "bO")
bR = tf.Variable(tf.zeros([1]), name = "bR")
bD = tf.Variable(tf.ones([1]), name="bD")

predicted_observation = tf.matmul(layer2M, wO, name = "predicted_observation") + bO

# "Clip" the reward
predicted_reward = tf.sigmoid(tf.matmul(layer2M, wR, name = "predicted_reward") + bR) * 0.1 + 0.95

predicted_done = tf.sigmoid(tf.matmul(layer2M, wD, name = "predicted_done") + bD)

true_observation = tf.placeholder(tf.float32, [None, 4], name = "true_observation")
true_reward = tf.placeholder(tf.float32, [None, 1], name = "true_reward")
true_done = tf.placeholder(tf.float32, [None, 1], name = "true_done")

predicted_state = tf.concat([predicted_observation, predicted_reward, predicted_done], 1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1 - predicted_done, 1 - true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate = learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions

# %%
def resetGradBuffer(gradBuffer):
    for ix, grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer



def discount_rewards(r):
    ################################################################################
    # TODO: Implement the discounted rewards function                              #
    # Return discounted rewards weighed by gamma. Each reward will be replaced     #
    # with a weight reward that involves itself and all the other rewards occuring #
    # after it. The later the reward after it happens, the less effect it has on   #
    # the current rewards's discounted reward                                      #
    # Hint: [r0, r1, r2, ..., r_N] will look someting like:                        #
    #       [(r0 + r1*gamma^1 + ... r_N*gamma^N), (r1 + r2*gamma^1 + ...), ...]    #
    ################################################################################

    result = np.zeros_like(r, dtype = np.float32)

    cumm = 0.0        
    for i in xrange(result.shape[0] - 1, -1, -1):
        cumm = cumm * gamma + r[i, 0]
        result[i, 0] = cumm        
    
    return result        
    
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################

    
    
# This function uses our model to produce a new state when given a previous state and action
# xs: Set of states
def stepModel(sess, xs, action):
    # Just feed the last state in the set xs
    toFeed = np.reshape(
        np.hstack([xs[-1][0], np.array(action)]),
        [1, 5]
    )
    
    myPredict = sess.run([predicted_state], feed_dict = {previous_state: toFeed})
    
    reward = myPredict[0][:, 4]
    
    observation = myPredict[0][:, 0: 4]
    observation[:, 0] = np.clip(observation[:, 0], -2.4, 2.4)
    observation[:, 2] = np.clip(observation[:, 2], -0.4, 0.4)
    
    doneP = np.clip(myPredict[0][:, 5], 0, 1)
        
    if doneP > 0.1 or len(xs) >= 300:
        done = True
    else:
        done = False
        
    return observation, reward, done

# %% [markdown]
# ## Training the Policy and Model

# %%
xs, drs, ys, ds = [], [], [], []
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1

init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model

trainThePolicy = False # Whether to train the policy

switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    
    sess.run(init)
    
    observation = env.reset()
    x = observation
    
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum / batch_size > 150 and drawFromModel == False) or rendering == True:           
            env.render()                
            rendering = True
            
        x = np.reshape(observation, [1, 4])

        tfprob = sess.run(probability, feed_dict = {observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # Record various intermediates (needed later for backprop)
        xs.append(x)
        
        y = 1 if action == 0 else 0    # "Fake" label
        ys.append(y)
        
        # Step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess, xs, action)
            
        reward_sum += reward
        
        ds.append(done * 1)
        
        # Record reward (has to be done after we call step() to get reward for previous action)
        drs.append(reward) 

        if done:
            episode_number += 1
            
            if drawFromModel == False: 
                real_episodes += 1

            # Stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            
            xs, drs, ys, ds = [], [], [], [] # Reset array memory
            
            if trainTheModel == True:                
                ################################################################################
                # TODO: Run the model network and compute predicted_state                      #
                # Output: 'pState'                                                             #
                ################################################################################
                
                state_nextsAll = np.hstack([epx, epr, epd])
                
                # Note: action & y is ALWAYS opposite
                epXandAction = np.hstack([epx, 1 - epy])
                
                pState, _ = sess.run([predicted_state, updateModel], feed_dict = {
                    previous_state: epXandAction,
                    true_observation: np.vstack([epx[1: ], observation]),
                    true_reward: epr,
                    true_done: epd
                })
                
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################                

            if trainThePolicy == True:
                
                ################################################################################
                # TODO: Run the policy network and compute newGrads                            #
                # Output: 'tGrad'                                                              #
                ################################################################################
                
                discounted_epr = discount_rewards(epr)
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr /= np.std(discounted_epr)
                
                tGrad = sess.run(newGrads, feed_dict = {
                    observations: epx,
                    input_y: epy,
                    advantages: discounted_epr
                })
                
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                    
                for ix, grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number:
                switch_point = episode_number
                
                if trainThePolicy == True:
                    
                    ################################################################################
                    # TODO:                                                                        #
                    # (1) Run the policy network and update gradients                              #
                    # (2) Reset gradBuffer to 0                                                    #
                    ################################################################################
                    
                    sess.run(updateGrads, feed_dict = {
                        W1Grad: gradBuffer[0],
                        W2Grad: gradBuffer[1]
                    })
                    
                    gradBuffer = resetGradBuffer(gradBuffer)
                    
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################

                running_reward = reward_sum if running_reward is None else (running_reward * 0.99 + reward_sum * 0.01)
                
                if drawFromModel == False:
                    print("World Perf: Episode %d. Reward %f. action: %f. mean reward %f." % (
                        real_episodes,
                        reward_sum / real_bs,
                        action,
                        running_reward / real_bs
                    ))
                    
                    if reward_sum / batch_size > 200:
                        break
                        
                reward_sum = 0

                # Once the model has been trained on 100 episodes
                if episode_number > 100:
                    
                    ################################################################################
                    # TODO: Alternating between training the policy from the model and training    #
                    # the model from the real environment.                                         #
                    ################################################################################                 
                    
                    drawFromModel = not drawFromModel
                    trainTheModel = not trainTheModel
                    
                    trainThePolicy = not trainThePolicy                    
                    
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1, 0.1, [4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4. Reward 10.000000. action: 0.000000. mean reward 10.000000.
# World Perf: Episode 7. Reward 15.333333. action: 0.000000. mean reward 10.053333.
# World Perf: Episode 10. Reward 14.000000. action: 0.000000. mean reward 10.092800.
# World Perf: Episode 13. Reward 19.333333. action: 1.000000. mean reward 10.185205.
# World Perf: Episode 16. Reward 14.000000. action: 0.000000. mean reward 10.223353.
# World Perf: Episode 19. Reward 13.333333. action: 1.000000. mean reward 10.254453.
# World Perf: Episode 22. Reward 13.000000. action: 1.000000. mean reward 10.281909.
# World Perf: Episode 25. Reward 12.666667. action: 1.000000. mean reward 10.305756.
# World Perf: Episode 28. Reward 25.333333. action: 0.000000. mean reward 10.456032.
# World Perf: Episode 31. Reward 19.333333. action: 0.000000. mean reward 10.544805.
# World Perf: Episode 34. Reward 16.333333. action: 0.000000. mean reward 10.602690.
# World Perf: Episode 37. Reward 12.666667. action: 0.000000. mean reward 10.623330.
# World Perf: Episode 40. Reward 16.666667. action: 0.000000. mean reward 10.683763.
# World Perf: Episode 43. Reward 15.000000. action: 0.000000. mean reward 10.726926.
# World Perf: Episode 46. Reward 13.000000. action: 0.000000. mean reward 10.749656.
# World Perf: Episode 49. Reward 13.000000. action: 0.000000. mean reward 10.772160.
# World Perf: Episode 52. Reward 20.666667. action: 0.000000. mean reward 10.871105.
# World Perf: Episode 55. Reward 19.666667. action: 1.000000. mean reward 10.959061.
# World Perf: Episode 58. Reward 13.333333. action: 0.000000. mean reward 10.982803.
# World Perf: Episode 61. Reward 19.666667. action: 1.000000. mean reward 11.069642.
# World Perf: Episode 64. Reward 30.666667. action: 0.000000. mean reward 11.265612.
# World Perf: Episode 67. Reward 10.333333. action: 1.000000. mean reward 11.256289.
# World Perf: Episode 70. Reward 14.333333. action: 0.000000. mean reward 11.287060.
# World Perf: Episode 73. Reward 12.000000. action: 1.000000. mean reward 11.294189.
# World Perf: Episode 76. Reward 17.000000. action: 0.000000. mean reward 11.351247.
# World Perf: Episode 79. Reward 21.666667. action: 0.000000. mean reward 11.454402.
# World Perf: Episode 82. Reward 16.666667. action: 0.000000. mean reward 11.506524.
# World Perf: Episode 2110. Reward 175.333333. action: 1.000000. mean reward 194.527695.
# World Perf: Episode 2113. Reward 176.000000. action: 0.000000. mean reward 195.388306.
# World Perf: Episode 2116. Reward 174.666667. action: 1.000000. mean reward 194.422684.
# World Perf: Episode 2119. Reward 187.000000. action: 0.000000. mean reward 192.756973.
# World Perf: Episode 2122. Reward 200.000000. action: 0.000000. mean reward 191.798645.
# World Perf: Episode 2125. Reward 162.000000. action: 0.000000. mean reward 192.572937.
# World Perf: Episode 2128. Reward 184.000000. action: 0.000000. mean reward 193.550217.
# World Perf: Episode 2131. Reward 181.333333. action: 1.000000. mean reward 194.480576.
# World Perf: Episode 2134. Reward 180.666667. action: 1.000000. mean reward 195.391251.
# World Perf: Episode 2137. Reward 172.000000. action: 1.000000. mean reward 196.193924.
# World Perf: Episode 2140. Reward 176.666667. action: 0.000000. mean reward 197.026840.
# World Perf: Episode 2143. Reward 200.000000. action: 0.000000. mean reward 197.597610.
# World Perf: Episode 2146. Reward 161.666667. action: 1.000000. mean reward 198.251266.
# World Perf: Episode 2149. Reward 199.000000. action: 0.000000. mean reward 197.526810.
# World Perf: Episode 2152. Reward 200.000000. action: 0.000000. mean reward 196.048096.
# World Perf: Episode 2155. Reward 195.333333. action: 0.000000. mean reward 196.296982.
# World Perf: Episode 2158. Reward 163.666667. action: 1.000000. mean reward 196.997482.
# World Perf: Episode 2161. Reward 180.666667. action: 1.000000. mean reward 197.853027.
# World Perf: Episode 2164. Reward 179.666667. action: 0.000000. mean reward 196.758438.
# World Perf: Episode 2167. Reward 188.000000. action: 0.000000. mean reward 195.673660.
# World Perf: Episode 2170. Reward 200.000000. action: 0.000000. mean reward 196.749878.
# World Perf: Episode 2173. Reward 149.666667. action: 0.000000. mean reward 197.301254.
# World Perf: Episode 2176. Reward 197.000000. action: 0.000000. mean reward 197.497452.
# World Perf: Episode 2179. Reward 170.666667. action: 1.000000. mean reward 198.243973.
# World Perf: Episode 2182. Reward 200.000000. action: 1.000000. mean reward 199.268051.
# World Perf: Episode 2185. Reward 199.666667. action: 0.000000. mean reward 200.270447.
# World Perf: Episode 2188. Reward 162.333333. action: 1.000000. mean reward 200.877686.
# World Perf: Episode 2191. Reward 192.333333. action: 1.000000. mean reward 201.773743.
# World Perf: Episode 2194. Reward 194.000000. action: 1.000000. mean reward 202.668137.
# World Perf: Episode 2197. Reward 200.000000. action: 1.000000. mean reward 201.291946.
# World Perf: Episode 2200. Reward 144.666667. action: 0.000000. mean reward 199.135574.
# World Perf: Episode 2203. Reward 178.333333. action: 1.000000. mean reward 199.926193.
# World Perf: Episode 2206. Reward 189.666667. action: 0.000000. mean reward 200.814880.
# World Perf: Episode 2209. Reward 177.000000. action: 0.000000. mean reward 201.558533.
# World Perf: Episode 2212. Reward 197.000000. action: 0.000000. mean reward 201.077866.
# World Perf: Episode 2215. Reward 182.000000. action: 0.000000. mean reward 201.866882.
# World Perf: Episode 2218. Reward 187.666667. action: 0.000000. mean reward 202.696045.
# World Perf: Episode 2221. Reward 157.333333. action: 0.000000. mean reward 203.206299.
# World Perf: Episode 2224. Reward 164.333333. action: 0.000000. mean reward 203.777969.
# World Perf: Episode 2227. Reward 183.333333. action: 0.000000. mean reward 204.526260.
# World Perf: Episode 2230. Reward 181.000000. action: 0.000000. mean reward 205.235779.
# World Perf: Episode 2233. Reward 177.333333. action: 1.000000. mean reward 205.894730.
# World Perf: Episode 2236. Reward 193.000000. action: 0.000000. mean reward 205.572205.
# World Perf: Episode 2239. Reward 200.000000. action: 1.000000. mean reward 204.144516.
# World Perf: Episode 2242. Reward 200.000000. action: 0.000000. mean reward 205.051559.
# World Perf: Episode 2245. Reward 196.000000. action: 1.000000. mean reward 205.900284.
# World Perf: Episode 2248. Reward 179.000000. action: 0.000000. mean reward 206.563004.
# World Perf: Episode 2251. Reward 200.000000. action: 1.000000. mean reward 205.940689.
# World Perf: Episode 2254. Reward 200.000000. action: 0.000000. mean reward 206.813049.
# World Perf: Episode 2257. Reward 198.333333. action: 1.000000. mean reward 207.650940.
# World Perf: Episode 2260. Reward 200.000000. action: 0.000000. mean reward 208.488235.
# World Perf: Episode 2263. Reward 184.666667. action: 0.000000. mean reward 209.060074.
# World Perf: Episode 2266. Reward 198.000000. action: 1.000000. mean reward 209.850327.
# World Perf: Episode 2269. Reward 175.000000. action: 0.000000. mean reward 210.395020.
# World Perf: Episode 2272. Reward 200.000000. action: 0.000000. mean reward 210.604065.
# World Perf: Episode 2275. Reward 200.000000. action: 1.000000. mean reward 210.350540.
# World Perf: Episode 2278. Reward 200.000000. action: 1.000000. mean reward 211.135254.
# World Perf: Episode 2281. Reward 178.333333. action: 0.000000. mean reward 210.987991.
# World Perf: Episode 2284. Reward 186.333333. action: 0.000000. mean reward 211.622925.
# World Perf: Episode 2287. Reward 172.000000. action: 1.000000. mean reward 210.976135.
# World Perf: Episode 2290. Reward 200.000000. action: 0.000000. mean reward 211.745712.
# World Perf: Episode 2293. Reward 200.000000. action: 1.000000. mean reward 212.499390.
# World Perf: Episode 2296. Reward 189.666667. action: 0.000000. mean reward 213.131287.
# World Perf: Episode 2299. Reward 172.000000. action: 1.000000. mean reward 213.577255.
# World Perf: Episode 2302. Reward 191.666667. action: 0.000000. mean reward 213.672318.
# World Perf: Episode 2305. Reward 200.000000. action: 1.000000. mean reward 214.390625.
# World Perf: Episode 2308. Reward 195.000000. action: 0.000000. mean reward 215.044495.
# World Perf: Episode 2311. Reward 177.666667. action: 0.000000. mean reward 215.191895.
# World Perf: Episode 2314. Reward 200.000000. action: 1.000000. mean reward 215.879623.
# World Perf: Episode 2317. Reward 200.000000. action: 0.000000. mean reward 216.553787.
# World Perf: Episode 2320. Reward 200.000000. action: 0.000000. mean reward 217.214737.
# World Perf: Episode 2323. Reward 200.000000. action: 0.000000. mean reward 217.861923.
# World Perf: Episode 2326. Reward 186.666667. action: 0.000000. mean reward 218.362778.
# World Perf: Episode 2329. Reward 200.000000. action: 0.000000. mean reward 216.561722.
# World Perf: Episode 2332. Reward 200.000000. action: 0.000000. mean reward 216.776489.
# World Perf: Episode 2449. Reward 200.000000. action: 1.000000. mean reward 222.821640.
# World Perf: Episode 2452. Reward 188.333333. action: 0.000000. mean reward 223.240677.
# World Perf: Episode 2455. Reward 158.000000. action: 0.000000. mean reward 223.352600.
# World Perf: Episode 2458. Reward 200.000000. action: 0.000000. mean reward 223.733749.
# World Perf: Episode 2461. Reward 196.666667. action: 1.000000. mean reward 224.216309.
# World Perf: Episode 2464. Reward 200.000000. action: 1.000000. mean reward 222.753830.
# World Perf: Episode 2467. Reward 195.333333. action: 0.000000. mean reward 220.977234.
# World Perf: Episode 2470. Reward 200.000000. action: 1.000000. mean reward 221.549149.
# World Perf: Episode 2473. Reward 200.000000. action: 1.000000. mean reward 222.109482.
# World Perf: Episode 2476. Reward 200.000000. action: 0.000000. mean reward 219.907288.
# World Perf: Episode 2479. Reward 200.000000. action: 1.000000. mean reward 220.038940.
# World Perf: Episode 2482. Reward 184.000000. action: 1.000000. mean reward 219.500244.
# World Perf: Episode 2485. Reward 200.000000. action: 1.000000. mean reward 217.439102.
# World Perf: Episode 2488. Reward 200.000000. action: 1.000000. mean reward 215.574081.
# World Perf: Episode 2491. Reward 183.000000. action: 0.000000. mean reward 213.563126.
# World Perf: Episode 2494. Reward 189.000000. action: 1.000000. mean reward 212.522537.
# World Perf: Episode 2497. Reward 197.000000. action: 0.000000. mean reward 211.912537.
# World Perf: Episode 2500. Reward 200.000000. action: 1.000000. mean reward 212.665527.
# World Perf: Episode 2503. Reward 199.000000. action: 1.000000. mean reward 213.393387.
# World Perf: Episode 2506. Reward 171.333333. action: 1.000000. mean reward 213.278305.
# World Perf: Episode 2509. Reward 200.000000. action: 1.000000. mean reward 212.389481.
# World Perf: Episode 2512. Reward 200.000000. action: 1.000000. mean reward 210.842773.
# World Perf: Episode 2515. Reward 200.000000. action: 0.000000. mean reward 210.903259.
# World Perf: Episode 2518. Reward 179.666667. action: 0.000000. mean reward 211.471558.
# World Perf: Episode 2521. Reward 200.000000. action: 1.000000. mean reward 212.233688.
# World Perf: Episode 2524. Reward 200.000000. action: 0.000000. mean reward 210.195023.
# World Perf: Episode 2527. Reward 200.000000. action: 0.000000. mean reward 210.981461.
# World Perf: Episode 2530. Reward 200.000000. action: 0.000000. mean reward 211.753006.
# World Perf: Episode 2533. Reward 190.666667. action: 0.000000. mean reward 212.416504.
# World Perf: Episode 2536. Reward 185.000000. action: 0.000000. mean reward 211.408630.
# World Perf: Episode 2539. Reward 185.333333. action: 1.000000. mean reward 209.800842.
# World Perf: Episode 2542. Reward 200.000000. action: 0.000000. mean reward 207.672012.
# World Perf: Episode 2545. Reward 194.333333. action: 1.000000. mean reward 206.522034.
# World Perf: Episode 2548. Reward 182.666667. action: 0.000000. mean reward 205.159592.
# World Perf: Episode 2551. Reward 184.666667. action: 1.000000. mean reward 204.197388.
# 2551

# %% [markdown]
# ### Checking model representation
# Here we can examine how well the model is able to approximate the true environment after training. The green line indicates the real environment, and the blue indicates model predictions.

# %%
plt.figure(figsize = (8, 12))

for i in range(6):
    plt.subplot(6, 2, 2 * i + 1)
    plt.plot(pState[:, i])
    plt.subplot(6, 2, 2 * i + 1)
    plt.plot(state_nextsAll[:, i])
    
plt.tight_layout()
